# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('PEP1.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
for i in range(len(data.columns)):
    colName = data.columns
    x = colName[i]
    print (x, ':', data[x].unique())
# Out:
# Id : [   1    2    3 ... 1458 1459 1460]
# MSSubClass : [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
# MSZoning : ['RL' 'RM' 'C (all)' 'FV' 'RH']
# LotFrontage : [ 65.  80.  68.  60.  84.  85.  75.  nan  51.  50.  70.  91.  72.  66.
#  101.  57.  44. 110.  98.  47. 108. 112.  74. 115.  61.  48.  33.  52.
#  100.  24.  89.  63.  76.  81.  95.  69.  21.  32.  78. 121. 122.  40.
#  105.  73.  77.  64.  94.  34.  90.  55.  88.  82.  71. 120. 107.  92.
#  134.  62.  86. 141.  97.  54.  41.  79. 174.  99.  67.  83.  43. 103.
#   93.  30. 129. 140.  35.  37. 118.  87. 116. 150. 111.  49.  96.  59.
#   36.  56. 102.  58.  38. 109. 130.  53. 137.  45. 106. 104.  42.  39.
#  144. 114. 128. 149. 313. 168. 182. 138. 160. 152. 124. 153.  46.]
# LotArea : [ 8450  9600 11250 ... 17217 13175  9717]
# Street : ['Pave' 'Grvl']
# Alley : [nan 'Grvl' 'Pave']
# LotShape : ['Reg' 'IR1' 'IR2' 'IR3']
# LandContour : ['Lvl' 'Bnk' 'Low' 'HLS']
# Utilities : ['AllPub' 'NoSeWa']
# ...

# %%
data['Neighborhood'].replace('mes', 'NAmes', inplace = True)

# %%
data['Neighborhood'].unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
data['BldgType'].replace('Twnhs', 'TwnhsI', inplace = True)

# %%
data['Exterior2nd'].replace('Brk Cmn', 'BrkComn', inplace = True)

# %%
data['Exterior2nd'].replace('Wd Shng', 'WdShing', inplace = True)

# %%
CatData = data.select_dtypes(include='object')

# %%
CatData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 43 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   Street         1460 non-null   object
#  2   Alley          91 non-null     object
#  3   LotShape       1460 non-null   object
#  4   LandContour    1460 non-null   object
#  5   Utilities      1460 non-null   object
#  6   LotConfig      1460 non-null   object
#  7   LandSlope      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   Condition1     1460 non-null   object
#  10  Condition2     1460 non-null   object
#  11  BldgType       1460 non-null   object
#  12  HouseStyle     1460 non-null   object
#  13  RoofStyle      1460 non-null   object
#  14  RoofMatl       1460 non-null   object
#  15  Exterior1st    1460 non-null   object
#  16  Exterior2nd    1460 non-null   object
# ...

# %%
NumData = data.select_dtypes(include='number')
NumData.drop(['MSSubClass','OverallQual','OverallCond','YearBuilt','YearRemodAdd','GarageYrBlt','MoSold','YrSold'],axis=1, inplace = True)

# %%
NumData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   LotFrontage    1201 non-null   float64
#  2   LotArea        1460 non-null   int64
#  3   MasVnrArea     1452 non-null   float64
#  4   BsmtFinSF1     1460 non-null   int64
#  5   BsmtFinSF2     1460 non-null   int64
#  6   BsmtUnfSF      1460 non-null   int64
#  7   TotalBsmtSF    1460 non-null   int64
#  8   1stFlrSF       1460 non-null   int64
#  9   2ndFlrSF       1460 non-null   int64
#  10  LowQualFinSF   1460 non-null   int64
#  11  GrLivArea      1460 non-null   int64
#  12  BsmtFullBath   1460 non-null   int64
#  13  BsmtHalfBath   1460 non-null   int64
#  14  FullBath       1460 non-null   int64
#  15  HalfBath       1460 non-null   int64
#  16  BedroomAbvGr   1460 non-null   int64
#  17  KitchebvGr     1460 non-null   int64
# ...

# %%
NumData.LotFrontage.fillna( data.LotFrontage.median() , inplace=True)
NumData.MasVnrArea.fillna( data.MasVnrArea.median() , inplace=True)

# %%
NumData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   LotFrontage    1460 non-null   float64
#  2   LotArea        1460 non-null   int64
#  3   MasVnrArea     1460 non-null   float64
#  4   BsmtFinSF1     1460 non-null   int64
#  5   BsmtFinSF2     1460 non-null   int64
#  6   BsmtUnfSF      1460 non-null   int64
#  7   TotalBsmtSF    1460 non-null   int64
#  8   1stFlrSF       1460 non-null   int64
#  9   2ndFlrSF       1460 non-null   int64
#  10  LowQualFinSF   1460 non-null   int64
#  11  GrLivArea      1460 non-null   int64
#  12  BsmtFullBath   1460 non-null   int64
#  13  BsmtHalfBath   1460 non-null   int64
#  14  FullBath       1460 non-null   int64
#  15  HalfBath       1460 non-null   int64
#  16  BedroomAbvGr   1460 non-null   int64
#  17  KitchebvGr     1460 non-null   int64
# ...

# %%
CatData[['Id','MSSubClass','OverallQual','OverallCond','YearBuilt','YearRemodAdd','GarageYrBlt','MoSold','YrSold']] = data[['Id','MSSubClass','OverallQual','OverallCond','YearBuilt','YearRemodAdd','GarageYrBlt','MoSold','YrSold']]

# %%
CatData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 52 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   Street         1460 non-null   object
#  2   Alley          91 non-null     object
#  3   LotShape       1460 non-null   object
#  4   LandContour    1460 non-null   object
#  5   Utilities      1460 non-null   object
#  6   LotConfig      1460 non-null   object
#  7   LandSlope      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   Condition1     1460 non-null   object
#  10  Condition2     1460 non-null   object
#  11  BldgType       1460 non-null   object
#  12  HouseStyle     1460 non-null   object
#  13  RoofStyle      1460 non-null   object
#  14  RoofMatl       1460 non-null   object
#  15  Exterior1st    1460 non-null   object
#  16  Exterior2nd    1460 non-null   object
# ...

# %%
for i in range(len(CatData.columns)):
    colName = CatData.columns
    x = colName[i]
    CatData[x].fillna( CatData[x].mode()[0], inplace=True)

# %%
CatData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 52 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   Street         1460 non-null   object
#  2   Alley          1460 non-null   object
#  3   LotShape       1460 non-null   object
#  4   LandContour    1460 non-null   object
#  5   Utilities      1460 non-null   object
#  6   LotConfig      1460 non-null   object
#  7   LandSlope      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   Condition1     1460 non-null   object
#  10  Condition2     1460 non-null   object
#  11  BldgType       1460 non-null   object
#  12  HouseStyle     1460 non-null   object
#  13  RoofStyle      1460 non-null   object
#  14  RoofMatl       1460 non-null   object
#  15  Exterior1st    1460 non-null   object
#  16  Exterior2nd    1460 non-null   object
# ...

# %%
NumData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   LotFrontage    1460 non-null   float64
#  2   LotArea        1460 non-null   int64
#  3   MasVnrArea     1460 non-null   float64
#  4   BsmtFinSF1     1460 non-null   int64
#  5   BsmtFinSF2     1460 non-null   int64
#  6   BsmtUnfSF      1460 non-null   int64
#  7   TotalBsmtSF    1460 non-null   int64
#  8   1stFlrSF       1460 non-null   int64
#  9   2ndFlrSF       1460 non-null   int64
#  10  LowQualFinSF   1460 non-null   int64
#  11  GrLivArea      1460 non-null   int64
#  12  BsmtFullBath   1460 non-null   int64
#  13  BsmtHalfBath   1460 non-null   int64
#  14  FullBath       1460 non-null   int64
#  15  HalfBath       1460 non-null   int64
#  16  BedroomAbvGr   1460 non-null   int64
#  17  KitchebvGr     1460 non-null   int64
# ...

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["LotFrontage"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3512751198.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["LotFrontage"])
# <Axes: xlabel='LotFrontage', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["LotArea"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3086091103.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["LotArea"])
# <Axes: xlabel='LotArea', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["MasVnrArea"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3871655260.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["MasVnrArea"])
# <Axes: xlabel='MasVnrArea', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["BsmtFinSF1"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3379288834.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["BsmtFinSF1"])
# <Axes: xlabel='BsmtFinSF1', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["BsmtFinSF2"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\1903974890.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["BsmtFinSF2"])
# <Axes: xlabel='BsmtFinSF2', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["BsmtUnfSF"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\2723378432.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["BsmtUnfSF"])
# <Axes: xlabel='BsmtUnfSF', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["TotalBsmtSF"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\2734527828.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["TotalBsmtSF"])
# <Axes: xlabel='TotalBsmtSF', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["1stFlrSF"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\752814380.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["1stFlrSF"])
# <Axes: xlabel='1stFlrSF', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["2ndFlrSF"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\813165738.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["2ndFlrSF"])
# <Axes: xlabel='2ndFlrSF', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["LowQualFinSF"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3566690856.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["LowQualFinSF"])
# <Axes: xlabel='LowQualFinSF', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["GrLivArea"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3526345234.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["GrLivArea"])
# <Axes: xlabel='GrLivArea', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["BsmtFullBath"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\1393624275.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["BsmtFullBath"])
# <Axes: xlabel='BsmtFullBath', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["BsmtHalfBath"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\1009435373.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["BsmtHalfBath"])
# <Axes: xlabel='BsmtHalfBath', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["FullBath"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\4092152691.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["FullBath"])
# <Axes: xlabel='FullBath', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["HalfBath"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\1039762580.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["HalfBath"])
# <Axes: xlabel='HalfBath', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["BedroomAbvGr"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\1155918843.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["BedroomAbvGr"])
# <Axes: xlabel='BedroomAbvGr', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["KitchebvGr"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\2244540760.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["KitchebvGr"])
# <Axes: xlabel='KitchebvGr', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["TotRmsAbvGrd"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\2734890752.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["TotRmsAbvGrd"])
# <Axes: xlabel='TotRmsAbvGrd', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["Fireplaces"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3603739977.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["Fireplaces"])
# <Axes: xlabel='Fireplaces', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["GarageCars"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\705575366.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["GarageCars"])
# <Axes: xlabel='GarageCars', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["GarageArea"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3435153190.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["GarageArea"])
# <Axes: xlabel='GarageArea', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["WoodDeckSF"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3862905180.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["WoodDeckSF"])
# <Axes: xlabel='WoodDeckSF', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["OpenPorchSF"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\1664911157.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["OpenPorchSF"])
# <Axes: xlabel='OpenPorchSF', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["EnclosedPorch"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\1738830069.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["EnclosedPorch"])
# <Axes: xlabel='EnclosedPorch', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["3SsnPorch"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\665658139.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["3SsnPorch"])
# <Axes: xlabel='3SsnPorch', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["ScreenPorch"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\531664577.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["ScreenPorch"])
# <Axes: xlabel='ScreenPorch', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["PoolArea"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\1983366851.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["PoolArea"])
# <Axes: xlabel='PoolArea', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["MiscVal"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\1247058489.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["MiscVal"])
# <Axes: xlabel='MiscVal', ylabel='Density'>

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))
sns.distplot(NumData["SalePrice"])
# Out:
# C:\Users\wisarut\AppData\Local\Temp\ipykernel_5212\3160617978.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(NumData["SalePrice"])
# <Axes: xlabel='SalePrice', ylabel='Density'>

# %%
NumCor = NumData.corr()
NumCor_des = NumCor.sort_values(by='SalePrice',ascending=False)
NumCor_des
# Out:
#                      Id  LotFrontage   LotArea  MasVnrArea  BsmtFinSF1  \
# SalePrice     -0.021917     0.334771  0.263843    0.472614    0.386420
# GrLivArea      0.008273     0.368007  0.263116    0.388052    0.208171
# GarageCars     0.016570     0.269539  0.154871    0.361945    0.224054
# GarageArea     0.017634     0.323511  0.180403    0.370884    0.296970
# TotalBsmtSF   -0.015415     0.363472  0.260833    0.360067    0.522396
# 1stFlrSF       0.010496     0.413773  0.299475    0.339850    0.445863
# FullBath       0.005587     0.180534  0.126031    0.272999    0.058543
# TotRmsAbvGrd   0.027239     0.320518  0.190015    0.279568    0.044316
# MasVnrArea    -0.051071     0.178469  0.103321    1.000000    0.261256
# Fireplaces    -0.019772     0.233221  0.271364    0.247015    0.260011
# BsmtFinSF1    -0.005024     0.214367  0.214103    0.261256    1.000000
# LotFrontage   -0.009921     1.000000  0.304522    0.178469    0.214367
# ...

# %%
col = ['SalePrice', 'TotalBsmtSF', '1stFlrSF', 'GarageCars', 'GarageArea', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd']

# %%
sns.pairplot(NumData[col])

# %%
sns.countplot(x='MSZoning',data = CatData)
CatData.MSZoning.replace({'RL':1, 'RM':2, 'C (all)':3, 'FV':4, 'RH':4}, inplace = True)

# %%
sns.countplot(x='Street',data = CatData)
CatData.Street.replace({'Pave':1, 'Grvl':2}, inplace = True)

# %%
sns.countplot(x='LotShape',data = CatData)
CatData.LotShape.replace({'Reg':1, 'IR1':2, 'IR2':3, 'IR3':4}, inplace = True)

# %%
sns.countplot(x='LandContour',data = CatData)
CatData.LandContour.replace({'Lvl':1, 'Bnk':2, 'Low':3, 'HLS':4}, inplace = True)

# %%
sns.countplot(x='Utilities',data = CatData)
CatData.Utilities.replace({'AllPub':1, 'NoSeWa':2}, inplace = True)

# %%
sns.countplot(x='LotConfig',data = CatData)
CatData.LotConfig.replace({'Inside':1, 'FR2':2, 'Corner':3, 'CulDSac':4, 'FR3':5}, inplace = True)

# %%
CatData.Neighborhood.unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
sns.countplot(x='Neighborhood',data = CatData)
CatData.Neighborhood.replace({'CollgCr':1, 'Veenker':2, 'Crawfor':3, 'NoRidge':4, 'Mitchel':5, 'Somerst':6,
       'NWAmes':7, 'OldTown':8, 'BrkSide':9, 'Sawyer':10, 'NridgHt':11, 'NAmes':12,
       'SawyerW':13, 'IDOTRR':14, 'MeadowV':15, 'Edwards':16, 'Timber':17, 'Gilbert':18,
       'StoneBr':19, 'ClearCr':20, 'NPkVill':21, 'Blmngtn':22, 'BrDale':23, 'SWISU':24,
       'Blueste':25}, inplace = True)

# %%
sns.countplot(x='Condition1',data = CatData)
CatData.Condition1.replace({'Norm':1, 'Feedr':2, 'PosN':3, 'Artery':4, 'RRAe':5,'RRNn':6,'RRAn':7,
                          'PosA':8,'RRNe':9}, inplace = True)

# %%
sns.countplot(x='Condition2',data = CatData)
CatData.Condition2.replace({'Norm':1, 'Feedr':2, 'PosN':3, 'Artery':4, 'RRAe':5,'RRNn':6,'RRAn':7,
                          'PosA':8,'RRNe':9}, inplace = True)

# %%
sns.countplot(x='BldgType',data = CatData)
CatData.BldgType.replace({'1Fam':1, '2fmCon':2, 'Duplex':3, 'TwnhsE':4, 'TwnhsI':5}, inplace = True)

# %%
sns.countplot(x='HouseStyle',data = CatData)
CatData.HouseStyle.replace({'2Story':1, '1Story':2, '1.5Fin':3, '1.5Unf':4, 'SFoyer':5,'SLvl':6,'2.5Unf':7,
                          '2.5Fin':8}, inplace = True)

# %%
sns.countplot(x='RoofStyle',data = CatData)
CatData.RoofStyle.replace({'Gable':1, 'Hip':2, 'Gambrel':3, 'Mansard':4, 'Flat':5,'Shed':6}, inplace = True)

# %%
sns.countplot(x='Heating',data = CatData)
CatData.Heating.replace({'GasA':1, 'GasW':2, 'Grav':3, 'Wall':4, 'OthW':5,'Floor':6}, inplace = True)

# %%
sns.countplot(x='HeatingQC',data = CatData)
CatData.HeatingQC.replace({'Ex':1, 'Gd':2, 'TA':3, 'Fa':4, 'Po':5}, inplace = True)

# %%
sns.countplot(x='CentralAir',data = CatData)
CatData.CentralAir.replace({'Y':1, 'N':2}, inplace = True)

# %%
sns.countplot(x='Electrical',data = CatData)
CatData.Electrical.replace({'SBrkr':1, 'FuseF':2, 'FuseA':3, 'FuseP':4, 'Mix':5}, inplace = True)

# %%
sns.countplot(x='KitchenQual',data = CatData)
CatData.KitchenQual.replace({'Ex':1, 'Gd':2, 'TA':3, 'Fa':4}, inplace = True)

# %%
sns.countplot(x='Functiol',data = CatData)
CatData.Functiol.replace({'Typ':1, 'Min1':2, 'Maj1':3, 'Min2':4,'Mod':5,'Maj2':6,'Sev':7}, inplace = True)

# %%
sns.countplot(x='FireplaceQu',data = CatData)
CatData.FireplaceQu.replace({'Ex':1, 'Gd':2, 'TA':3, 'Fa':4, 'Po':5}, inplace = True)

# %%
sns.countplot(x='GarageType',data = CatData)
CatData.GarageType.replace({'Attchd':1, 'Detchd':2, 'BuiltIn':3, 'CarPort':4,'Basment':5,'2Types':6}, inplace = True)

# %%
sns.countplot(x='GarageFinish',data = CatData)
CatData.GarageFinish.replace({'RFn':1, 'Unf':2, 'Fin':3}, inplace = True)

# %%
sns.countplot(x='GarageQual',data = CatData)
CatData.GarageQual.replace({'Ex':1, 'Gd':2, 'TA':3, 'Fa':4,'Po':5}, inplace = True)

# %%
sns.countplot(x='GarageCond',data = CatData)
CatData.GarageCond.replace({'Ex':1, 'Gd':2, 'TA':3, 'Fa':4,'Po':5}, inplace = True)

# %%
sns.countplot(x='PavedDrive',data = CatData)
CatData.PavedDrive.replace({'Y':1, 'N':2, 'P':3}, inplace = True)

# %%
sns.countplot(x='PoolQC',data = CatData)
CatData.PoolQC.replace({'Ex':1, 'Gd':2, 'Fa':4}, inplace = True)

# %%
sns.countplot(x='Fence',data = CatData)
CatData.Fence.replace({'MnPrv':1, 'GdWo':2, 'GdPrv':3, 'MnWw':4}, inplace = True)

# %%
sns.countplot(x='MiscFeature',data = CatData)
CatData.MiscFeature.replace({'Shed':1, 'Gar2':2, 'Othr':3, 'TenC':4}, inplace = True)

# %%
sns.countplot(x='SaleType',data = CatData)
CatData.SaleType.replace({'WD':1, 'New':2, 'COD':3, 'ConLD':4,'ConLI':5,'CWD':6,'ConLw':7,'Con':8,'Oth':9}, inplace = True)

# %%
sns.countplot(x='SaleCondition',data = CatData)
CatData.SaleCondition.replace({'Normal':1, 'Abnorml':2, 'Partial':3, 'AdjLand':4,'Alloca':5,'Family':6}, inplace = True)

# %%
sns.countplot(x='MSSubClass',data = CatData)
# Out:
# <Axes: xlabel='MSSubClass', ylabel='count'>

# %%
sns.countplot(x='OverallQual',data = CatData)
# Out:
# <Axes: xlabel='OverallQual', ylabel='count'>

# %%
sns.countplot(x='OverallCond',data = CatData)
# Out:
# <Axes: xlabel='OverallCond', ylabel='count'>

# %%
sns.countplot(x='YearBuilt',data = CatData)
# Out:
# <Axes: xlabel='YearBuilt', ylabel='count'>

# %%
sns.countplot(x='YearRemodAdd',data = CatData)
# Out:
# <Axes: xlabel='YearRemodAdd', ylabel='count'>

# %%
sns.countplot(x='GarageYrBlt',data = CatData)
# Out:
# <Axes: xlabel='GarageYrBlt', ylabel='count'>

# %%
sns.countplot(x='MoSold',data = CatData)
# Out:
# <Axes: xlabel='MoSold', ylabel='count'>

# %%
sns.countplot(x='YrSold',data = CatData)
# Out:
# <Axes: xlabel='YrSold', ylabel='count'>

# %%
sns.countplot(x='RoofMatl',data = CatData)
CatData.RoofMatl.replace({'CompShg':1, 'WdShngl':2, 'Metal':3, 'WdShake':4,'Membran':5,'Tar&Grv':6,
                          'Roll':7,'ClyTile':8}, inplace = True)

# %%
CatData.Exterior1st.unique()
# Out:
# array(['VinylSd', 'MetalSd', 'Wd Sdng', 'HdBoard', 'BrkFace', 'WdShing',
#        'CemntBd', 'Plywood', 'AsbShng', 'Stucco', 'BrkComm', 'AsphShn',
#        'Stone', 'ImStucc', 'CBlock'], dtype=object)

# %%
sns.countplot(x='Exterior1st',data = CatData)
CatData.Exterior1st.replace({'VinylSd':1, 'MetalSd':2, 'Wd Sdng':3, 'HdBoard':4, 'BrkFace':5, 'WdShing':6,
       'CemntBd':7, 'Plywood':8, 'AsbShng':9, 'Stucco':10, 'BrkComm':11, 'AsphShn':12,
       'Stone':13, 'ImStucc':14, 'CBlock':15}, inplace = True)

# %%
CatData.Exterior2nd.unique()
# Out:
# array(['VinylSd', 'MetalSd', 'WdShing', 'HdBoard', 'Plywood', 'Wd Sdng',
#        'CmentBd', 'BrkFace', 'Stucco', 'AsbShng', 'BrkComn', 'ImStucc',
#        'AsphShn', 'Stone', 'Other', 'CBlock'], dtype=object)

# %%
sns.countplot(x='Exterior2nd',data = CatData)
CatData.Exterior2nd.replace({'VinylSd':1, 'MetalSd':2, 'Wd Sdng':3, 'HdBoard':4, 'BrkFace':5, 'WdShing':6,
       'CmentBd':7, 'Plywood':8, 'AsbShng':9, 'Stucco':10, 'BrkComn':11, 'AsphShn':12,
       'Stone':13, 'ImStucc':14, 'CBlock':15,'Other':16}, inplace = True)

# %%
sns.countplot(x='MasVnrType',data = CatData)
CatData.MasVnrType.replace({'BrkFace':1, 'None':2, 'Stone':3, 'BrkCmn':4}, inplace = True)

# %%
sns.countplot(x='ExterQual',data = CatData)
CatData.ExterQual.replace({'Ex':1, 'Gd':2, 'TA':3, 'Fa':4}, inplace = True)

# %%
sns.countplot(x='ExterCond',data = CatData)
CatData.ExterCond.replace({'Ex':1, 'Gd':2, 'TA':3, 'Fa':4,'Po':5}, inplace = True)

# %%
sns.countplot(x='Foundation',data = CatData)
CatData.Foundation.replace({'PConc':1, 'CBlock':2, 'BrkTil':3, 'Wood':4,'Slab':5,'Stone':6}, inplace = True)

# %%
sns.countplot(x='BsmtQual',data = CatData)
CatData.BsmtQual.replace({'Ex':1, 'Gd':2, 'TA':3, 'Fa':4}, inplace = True)

# %%
sns.countplot(x='BsmtCond',data = CatData)
CatData.BsmtCond.replace({'Ex':1, 'Gd':2, 'TA':3, 'Fa':4,'Po':5}, inplace = True)

# %%
sns.countplot(x='BsmtExposure',data = CatData)
CatData.BsmtExposure.replace({'No':1, 'Gd':2, 'Mn':3, 'Av':4}, inplace = True)

# %%
sns.countplot(x='BsmtFinType1',data = CatData)
CatData.BsmtFinType1.replace({'GLQ':1, 'ALQ':2, 'Unf':3, 'Rec':4,'BLQ':5,'LwQ':6}, inplace = True)

# %%
sns.countplot(x='BsmtFinType2',data = CatData)
CatData.BsmtFinType2.replace({'GLQ':1, 'ALQ':2, 'Unf':3, 'Rec':4,'BLQ':5,'LwQ':6}, inplace = True)

# %%
sns.countplot(x='Alley',data = CatData)
CatData.Alley.replace({'Grvl':1, 'Pave':2}, inplace = True)

# %%
sns.countplot(x='LandSlope',data = CatData)
CatData.LandSlope.replace({'Gtl':1, 'Mod':2, 'Sev':3}, inplace = True)

# %%
CatData.insert(0,'SalePrice',NumData['SalePrice'])
CatCor = CatData.corr()
CatCor_des = CatCor.sort_values(by='SalePrice',ascending=False)
CatCor_des
# Out:
#                SalePrice  MSZoning    Street     Alley  LotShape  LandContour  \
# SalePrice       1.000000 -0.113893 -0.041036 -0.027655  0.267759     0.092009
# OverallQual     0.790982 -0.007083 -0.058823  0.038768  0.198994     0.039133
# YearBuilt       0.522897 -0.054079 -0.021137 -0.016612  0.229365    -0.029314
# YearRemodAdd    0.507101  0.044124 -0.065465  0.073423  0.175488    -0.007847
# GarageYrBlt     0.397778  0.050550 -0.016382  0.011727  0.170560    -0.015536
# LotShape        0.267759 -0.173931  0.010129 -0.040861  1.000000     0.201047
# BsmtExposure    0.229632 -0.070648  0.045421 -0.061661  0.106951     0.078411
# RoofStyle       0.159332 -0.091883  0.006881  0.000135  0.043063     0.100625
# SaleCondition   0.142503  0.073398  0.022919  0.026392 -0.004773     0.062826
# GarageFinish    0.141148  0.002580 -0.010497 -0.034434  0.067334     0.055327
# LotConfig       0.109106 -0.095379  0.004458 -0.042934  0.308073     0.021107
# ...

# %%
import pandas as pd
from scipy import stats
from scipy.stats import ttest_rel

ttest,pval = stats.ttest_rel(CatData['OverallQual'], CatData['SalePrice'])
print(x,':',ttest,pval)
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# YrSold : -87.01703839543478 0.0
# reject null hypothesis

# %%
from scipy.stats import chi2_contingency

stat, p_value, dof, chi_array = chi2_contingency(CatData['OverallQual'], NumData['SalePrice'])
p_value
# Out:
# 1.0

# %%
new_CatData = CatData[['OverallQual','YearBuilt', 'YearRemodAdd','Id']]

# %%
new_NumData = NumData[['Id','TotRmsAbvGrd','FullBath','1stFlrSF','TotalBsmtSF','GarageArea','GarageCars','GrLivArea','SalePrice']]

# %%
new_Data = pd.merge(new_CatData, new_NumData, on = 'Id')

# %%
new_Data
# Out:
#       OverallQual  YearBuilt  YearRemodAdd    Id  TotRmsAbvGrd  FullBath  \
# 0               7       2003          2003     1             8         2
# 1               6       1976          1976     2             6         2
# 2               7       2001          2002     3             6         2
# 3               7       1915          1970     4             7         1
# 4               8       2000          2000     5             9         2
# ...           ...        ...           ...   ...           ...       ...
# 1455            6       1999          2000  1456             7         2
# 1456            6       1978          1988  1457             7         2
# 1457            7       1941          2006  1458             9         2
# 1458            5       1950          1996  1459             5         1
# 1459            5       1965          1965  1460             6         1
#
#       1stFlrSF  TotalBsmtSF  GarageArea  GarageCars  GrLivArea  SalePrice
# ...

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation = 45)
sns.boxplot(x = 'SalePrice', data = new_Data)
# Out:
# <Axes: xlabel='SalePrice'>

# %%
def outlier_treatment(col):
    sorted(col)
    Q1,Q3 = np.percentile(col , [25,75])
    IQR = Q3 - Q1
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range


lower_range,upper_range = outlier_treatment(new_Data['SalePrice'])
print("Lower Range:",lower_range)
print("Upper Range:",upper_range)
# Out:
# Lower Range: 4000.0
# Upper Range: 339800.0

# %%
new_Data.drop(new_Data[(new_Data['SalePrice']>339800.0) & (new_Data['SalePrice'] < 4000.0)].index, inplace=True)
